# %%
print('Hello Jupyter!')

# %%
4 + 3
# Out:
# 7

# %%
3**4
# Out:
# 81

# %% [markdown]
# User single _underscores_ or sigle *asterisks* to get italics

# %% [markdown]
# User double __underscores__ or double **asterisks** to get bold

# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3

# %% [markdown]
# * item 1
# * item 2
# * item 3
#   * sub-item 1

# %% [markdown]
# ```python
# s = "Syntax highlighting for Python"
# print(x)
# ```

# %% [markdown]
# ![logo.jpg](attachment:logo.jpg)
